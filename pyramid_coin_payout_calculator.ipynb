# %%
#Pyramid Coin proof of concept using Python3 before transcribing into Chialisp
AMT = 250000000000 #in mojos
QTY_XCH_ADDRESSES = 70 #number of XCH addresses to be paid out
XCH_TO_USD_CONVERSION = 25 #price of XCH in $USD

#functions
def get_xch_addresses(qty):
  xch_addresses = []
  for index_num in range(0,qty+1):
    xch_addresses.append("0xDEADBEEF{}".format(index_num))

  return xch_addresses

def count_addresses(xch_addresses): #How many addresses?

    return len(xch_addresses)


def levels_deep(blocks): #How many levels deep? ...in the pyramid
    height = 0
    inlayer = 1
    while inlayer <= blocks:
        height += 1
        #print("height{}: {}".format(i,height))
        blocks -= 2**inlayer
        #print("blocks: {}".format(blocks))
        inlayer += 1
        #print("inlayer: {}\n".format(inlayer))
    return height

def get_position(xch_addresses,address): #one specific position in the pyramid

    return xch_addresses.index(address)

def units_per_level(level): #total units in each level. used to calculate payout per unit.

    units = 2**level + 1
    return units

def remainder_in_units(total_addresses):  #deepest level will most times not fill every position yet those positions are still used to calculate the payouts
    levels = levels_deep(total_addresses)
    #print("Levels: {}".format(levels))
    if levels == 1:
        remainder = int(3 - total_addresses)
    else:
        accum_units = 0
        for level in range(1,levels+1):
            level_units = units_per_level(level)
            accum_units += level_units
            #print("Accumulated Units: {}".format(accum_units))
        remainder = accum_units - total_addresses
    return remainder

def remainder_mojos(amt_level,units_in_level,remainder_units): #remaining units x unit value gives remainder which all goes to the first payout address as a bonus

    remainder_mojos = int(amt_level/units_in_level * remainder_units)

    return remainder_mojos

print("Total Coin Value: {:,} mojos".format(AMT))
total_addresses = QTY_XCH_ADDRESSES
print("Total Payout Addresses: {}".format(total_addresses))
total_levels = levels_deep(total_addresses)
print("Total Pyramid Levels: {}".format(total_levels))
level_amt = int(AMT/total_levels)
print("Amount Per Level: {:,}".format(level_amt))
remainder = remainder_in_units(total_addresses)
print("Remaining Units: {} of {} in bottom level {}".format(remainder,units_per_level(total_levels),total_levels))
remainder_mojos = remainder_mojos(level_amt,units_per_level(total_levels),remainder) #fix this
print("Remaining Mojos: {}".format(remainder_mojos))
print("\n")
#index postion loop
XCH_ADDRESSES = get_xch_addresses(QTY_XCH_ADDRESSES)
for address in XCH_ADDRESSES:
    address_position = get_position(XCH_ADDRESSES,address) + 1 # add one to accomodate lisp which has no python list index
    print("Address Position{}: {}".format(address_position,address))
    level = levels_deep(address_position)
    #print("Level: {}".format(level))
    units_in_level = units_per_level(level)
    print("Units on Level {}: {}".format(level,units_in_level))
    unit_value = int(level_amt/units_in_level)
    print("Value Per Unit on Level {}: {}".format(level,unit_value))
    if address_position == 1:
        first_payout = unit_value + remainder_mojos
        usd = first_payout*XCH_TO_USD_CONVERSION/1000000000000
        print("*First Position Payout Value: {:,} Mojos or USD${}".format(first_payout,usd))
        #print("{} = unit value {} plus remainder {}".format(first_payout,unit_value,remainder_mojos))
    else:
        usd = unit_value*XCH_TO_USD_CONVERSION/1000000000000
        print("Payout Level {} Value: {:,} Mojos or USD${}".format(level,unit_value,usd))
    print("\n")
print("*First Position Payout Value = Unit Value + REMAINDER")
# Out:
# Total Coin Value: 250,000,000,000 mojos
# Total Payout Addresses: 70
# Total Pyramid Levels: 6
# Amount Per Level: 41,666,666,666
# Remaining Units: 62 of 65 in bottom level 6
# Remaining Mojos: 39743589742
#
#
# Address Position1: 0xDEADBEEF0
# Units on Level 1: 3
# Value Per Unit on Level 1: 13888888888
# *First Position Payout Value: 53,632,478,630 Mojos or USD$1.34081196575
#
#
# Address Position2: 0xDEADBEEF1
# Units on Level 1: 3
# Value Per Unit on Level 1: 13888888888
# Payout Level 1 Value: 13,888,888,888 Mojos or USD$0.3472222222
#
#
# Address Position3: 0xDEADBEEF2
# Units on Level 1: 3
# Value Per Unit on Level 1: 13888888888
# Payout Level 1 Value: 13,888,888,888 Mojos or USD$0.3472222222
#
#
# Address Position4: 0xDEADBEEF3
# Units on Level 2: 5
# Value Per Unit on Level 2: 8333333333
# Payout Level 2 Value: 8,333,333,333 Mojos or USD$0.208333333325
#
#
# Address Position5: 0xDEADBEEF4
# Units on Level 2: 5
# Value Per Unit on Level 2: 8333333333
# Payout Level 2 Value: 8,333,333,333 Mojos or USD$0.208333333325
#
#
# Address Position6: 0xDEADBEEF5
# Units on Level 2: 5
# Value Per Unit on Level 2: 8333333333
# Payout Level 2 Value: 8,333,333,333 Mojos or USD$0.208333333325
#
#
# Address Position7: 0xDEADBEEF6
# Units on Level 2: 5
# Value Per Unit on Level 2: 8333333333
# Payout Level 2 Value: 8,333,333,333 Mojos or USD$0.208333333325
#
#
# Address Position8: 0xDEADBEEF7
# Units on Level 2: 5
# Value Per Unit on Level 2: 8333333333
# Payout Level 2 Value: 8,333,333,333 Mojos or USD$0.208333333325
#
#
# Address Position9: 0xDEADBEEF8
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position10: 0xDEADBEEF9
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position11: 0xDEADBEEF10
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position12: 0xDEADBEEF11
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position13: 0xDEADBEEF12
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position14: 0xDEADBEEF13
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position15: 0xDEADBEEF14
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position16: 0xDEADBEEF15
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position17: 0xDEADBEEF16
# Units on Level 3: 9
# Value Per Unit on Level 3: 4629629629
# Payout Level 3 Value: 4,629,629,629 Mojos or USD$0.115740740725
#
#
# Address Position18: 0xDEADBEEF17
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position19: 0xDEADBEEF18
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position20: 0xDEADBEEF19
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position21: 0xDEADBEEF20
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position22: 0xDEADBEEF21
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position23: 0xDEADBEEF22
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position24: 0xDEADBEEF23
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position25: 0xDEADBEEF24
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position26: 0xDEADBEEF25
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position27: 0xDEADBEEF26
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position28: 0xDEADBEEF27
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position29: 0xDEADBEEF28
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position30: 0xDEADBEEF29
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position31: 0xDEADBEEF30
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position32: 0xDEADBEEF31
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position33: 0xDEADBEEF32
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position34: 0xDEADBEEF33
# Units on Level 4: 17
# Value Per Unit on Level 4: 2450980392
# Payout Level 4 Value: 2,450,980,392 Mojos or USD$0.0612745098
#
#
# Address Position35: 0xDEADBEEF34
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position36: 0xDEADBEEF35
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position37: 0xDEADBEEF36
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position38: 0xDEADBEEF37
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position39: 0xDEADBEEF38
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position40: 0xDEADBEEF39
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position41: 0xDEADBEEF40
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position42: 0xDEADBEEF41
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position43: 0xDEADBEEF42
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position44: 0xDEADBEEF43
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position45: 0xDEADBEEF44
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position46: 0xDEADBEEF45
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position47: 0xDEADBEEF46
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position48: 0xDEADBEEF47
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position49: 0xDEADBEEF48
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position50: 0xDEADBEEF49
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position51: 0xDEADBEEF50
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position52: 0xDEADBEEF51
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position53: 0xDEADBEEF52
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position54: 0xDEADBEEF53
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position55: 0xDEADBEEF54
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position56: 0xDEADBEEF55
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position57: 0xDEADBEEF56
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position58: 0xDEADBEEF57
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position59: 0xDEADBEEF58
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position60: 0xDEADBEEF59
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position61: 0xDEADBEEF60
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position62: 0xDEADBEEF61
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position63: 0xDEADBEEF62
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position64: 0xDEADBEEF63
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position65: 0xDEADBEEF64
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position66: 0xDEADBEEF65
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position67: 0xDEADBEEF66
# Units on Level 5: 33
# Value Per Unit on Level 5: 1262626262
# Payout Level 5 Value: 1,262,626,262 Mojos or USD$0.03156565655
#
#
# Address Position68: 0xDEADBEEF67
# Units on Level 6: 65
# Value Per Unit on Level 6: 641025641
# Payout Level 6 Value: 641,025,641 Mojos or USD$0.016025641025
#
#
# Address Position69: 0xDEADBEEF68
# Units on Level 6: 65
# Value Per Unit on Level 6: 641025641
# Payout Level 6 Value: 641,025,641 Mojos or USD$0.016025641025
#
#
# Address Position70: 0xDEADBEEF69
# Units on Level 6: 65
# Value Per Unit on Level 6: 641025641
# Payout Level 6 Value: 641,025,641 Mojos or USD$0.016025641025
#
#
# Address Position71: 0xDEADBEEF70
# Units on Level 6: 65
# Value Per Unit on Level 6: 641025641
# Payout Level 6 Value: 641,025,641 Mojos or USD$0.016025641025
#
#
# *First Position Payout Value = Unit Value + REMAINDER
